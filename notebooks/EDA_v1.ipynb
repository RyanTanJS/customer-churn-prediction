# %%
import pandas as pd,numpy as np,matplotlib.pyplot as plt,seaborn as sns
df = pd.read_csv('../data/processed/telco_churn_clean_v1.csv')

# %%
changeType = [
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaperlessBilling",
    "PaymentMethod",
    "Churn"]

for col in changeType:
    df[col] = df[col].astype('category')

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   object
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   category
#  8   InternetService   7032 non-null   category
#  9   OnlineSecurity    7032 non-null   category
#  10  OnlineBackup      7032 non-null   category
#  11  DeviceProtection  7032 non-null   category
#  12  TechSupport       7032 non-null   category
#  13  StreamingTV       7032 non-null   category
#  14  StreamingMovies   7032 non-null   category
#  15  Contract          7032 non-null   category
# ...

# %%
categories = [
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaperlessBilling",
    "PaymentMethod",
    "Churn"]


for col in categories:
    plt.figure(figsize=(6,4))
    sns.countplot(x=col,data=df)
    plt.title(f'distribution of {col}')
    plt.show()

# %%
numericCategories=[
    'tenure',
    'MonthlyCharges',
    'TotalCharges']

for col in numericCategories:
    plt.figure(figsize=(6,4))
    sns.histplot(x=col,data=df)
    plt.title(f'distribution of {col}')
    plt.show()

# %%
for col in numericCategories:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=col,data=df)
    plt.title(f'distribution of {col}')
    plt.plot()

# %% [markdown]
# bivariate analysis

# %%
sns.countplot(x='Contract',hue='Churn',data=df)
plt.title('Churn rate by contract type')
plt.plot()
# Out:
# []

# %%
sns.countplot(x='TechSupport',hue='Churn',data=df)
plt.title('Churn rate by tech support type')
plt.plot()
# Out:
# []

# %%
sns.countplot(x='OnlineSecurity',hue='Churn',data=df)
plt.title('Churn rate by security type')
plt.plot()
# Out:
# []

# %%
sns.boxplot(x='MonthlyCharges',hue='Churn',data=df)
plt.title('Churn rate by monthly charge amount')
plt.plot()
# Out:
# []

# %%
sns.boxplot(x='tenure',hue='Churn',data=df)
plt.title('Churn rate by tenure')
plt.plot()
# Out:
# []

# %% [markdown]
# # Findings so far
#
# ### - Churn rate : 26%
#
# ### - Customers on a month-to-month contract tend to Churn more often
#
# ### - Customers that pay more per month Churn more often
#
# ### - New customers tend to Churn more often
#
# ### - Customers with no online security tend to churn more often
#
# ### - Customers with no tech support tend to churn more often
